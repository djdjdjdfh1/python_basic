# %%
import seaborn as sns
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.pivot(index='year', columns='month', values='passengers')
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
import matplotlib.pyplot as plt
# 연도별 승객수의 변화 lineplot - sns
# sns.lineplot(data=flights, x='year', y='passengers', errorbar=('ci', 95))
# sns.lineplot(data=flights, x='year', y='passengers', errorbar=None)
sns.lineplot(data=flights, x='year', y='passengers')
# sns 시각화는 신뢰구간도 같이 표시하는 경우
# 데이터가 변동될수 있는 구간
# 신뢰구간이 넓으면 불확실성이 크다 (데이터 분산이 크거나 샘플수가 적음)
# 신뢰구간이 좁으면 안정적 (데이터가 모여있거나 샘플수가 많을 경우)
# plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\playdata2\AppData\Local\Temp\ipykernel_12220\123251371.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='best')

# %%
# 년도별 월별 승객의 변화 시각화
plt.figure(figsize=(12,5))
sns.lineplot(data=flights, x='year', y='passengers', hue='month')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>
